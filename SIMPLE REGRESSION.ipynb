# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

data=pd.read_csv(r"C:/Users/HP/Downloads/placement.csv")
print(data)
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
x=data[["cgpa"]]
y=data["package"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[ 6.89]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.92962016])

# %%
lr.score(x_test,y_test)*100 #accuracy
# Out:
# 77.30984312051673

# %%
lr.coef_  #m=slope
# Out:
# array([0.57425647])

# %%
lr.intercept_ # c=intercept
# Out:
# np.float64(-1.0270069374542108)

# %%
0.57425647*6.89-1.0270069374542108 #y=mx+c where x=6.89
# Out:
# 2.929620140845789

# %%
sns.scatterplot(x="cgpa",y="package",data=data,label="org data")
plt.plot(data["cgpa"],lr.predict(x),color="red",label="predict line")
plt.legend()
plt.savefig("predict.jpg")
plt.show()
